# %%
import networkx as nx
from reducer import*
import matplotlib.pyplot as plt


def show_graph(graph):
    nx.draw(graph, with_labels=True)
    plt.show()

# %%
g1 = nx.DiGraph()
g1.add_edge('x','m')
g1.add_edge('m','y')
g1.add_edge('c','x')
g1.add_edge('c','y')
g1.add_edge('x','y')
xs1 = ['x']
ys1 = ['y']

print('Full Graph:')
show_graph(g1)
rg1, confs1 = reducer(g1, xs1, ys1, remove_precision=True,  project_confs=True,  project_causes=True)
print('Reduced Graph:')
show_graph(rg1)

g2 = nx.DiGraph()
g2.add_edge('x','m')
g2.add_edge('m','y')
g2.add_edge('x','y')
g2.add_edge('c1','x')
g2.add_edge('c1','c2')
g2.add_edge('c2','y')
xs2 = ['x']
ys2 = ['y']

print('Full Graph:')
show_graph(g2)
rg2, confs2 = reducer(g2, xs2, ys2, remove_precision=True,  project_confs=True,  project_causes=True)
print('Reduced Graph:')
show_graph(rg2)


g3 = nx.DiGraph()
g3.add_edge('x','m')
g3.add_edge('m','y')
g3.add_edge('x','y')
g3.add_edge('c1','m')
g3.add_edge('c1','y')
g3.add_edge('x','y')
xs3 = ['x']
ys3 = ['y']

print('Full Graph:')
show_graph(g3)
rg3, confs3 = reducer(g3, xs3, ys3, remove_precision=True,  project_confs=True,  project_causes=True)
print('Reduced Graph:')
show_graph(rg3)


g4 = nx.DiGraph()
g4.add_edge('A','B')
g4.add_edge('B','C')
g4.add_edge('C','F')
g4.add_edge('D','E')
g4.add_edge('E','F')
g4.add_edge('E','C')
g4.add_edge('c1','A')
g4.add_edge('c1','D')
g4.add_edge('c2','D')
g4.add_edge('c2','E')
g4.add_edge('c3','A')
g4.add_edge('c3','F')
g4.add_edge('c4', 'c5')
g4.add_edge('c4', 'A')
g4.add_edge('c5', 'C')
xs4 = ['A', 'D']
ys4 = ['C', 'F']

print('Full Graph:')
show_graph(g4)
rg4, confs4 = reducer(g4, xs4, ys4, remove_precision=True,  project_confs=True,  project_causes=True)
print('Reduced Graph:')
show_graph(rg4)

g5 = nx.DiGraph()
g5.add_edge('x','m')
g5.add_edge('m','y')
g5.add_edge('y','u')
g5.add_edge('y','q')
g5.add_edge('m','q')
g5.add_edge('q','p')
g5.add_edge('r','y')
g5.add_edge('o','x')
g5.add_edge('x','z')
g5.add_edge('c1','c2')
g5.add_edge('c2','y')
g5.add_edge('c1','x')
g5.add_edge('c1','m')
xs5 = ['x']
ys5 = ['p']

print('Full Graph:')
show_graph(g5)
rg5, confs5 = reducer(g5, xs5, ys5, remove_precision=True,  project_confs=True,  project_causes=True)
print('Reduced Graph:')
show_graph(rg5)

g6 = nx.DiGraph()
g6.add_edge('x','m')
g6.add_edge('m','y')
g6.add_edge('m','n')
g6.add_edge('n','y')
g6.add_edge('c1','x')
g6.add_edge('c1','y')
xs6 = ['x']
ys6 = ['y']


print('Full Graph:')
show_graph(g6)
rg6, confs6 = reducer(g6, xs6, ys6, remove_precision=True,  project_confs=True,  project_causes=True)
print('Reduced Graph:')
show_graph(rg6)
# Out:
# Full Graph:
# Reduced Graph:
# Full Graph:
# Reduced Graph:
# Full Graph:
# Reduced Graph:
# Full Graph:
# Reduced Graph:
# Full Graph:
# Reduced Graph:
# Full Graph:
# Reduced Graph:
